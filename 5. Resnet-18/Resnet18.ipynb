# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler

import torch.backends.cudnn as cudnn
import torch.nn as nn
import torch.nn.functional as F

import torch.optim as optim

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
seed = 42
torch.manual_seed(seed)

device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
# Out:
# cuda

# %%
num_workers = 0
batch_size = 20
valid_size = 0.2

transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

#Only the data is normalaized we do not need to augment the test data
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

train_data = torchvision.datasets.CIFAR10('data', train=True,
                              download=True, transform=transform_train)
test_data = torchvision.datasets.CIFAR10('data', train=False,
                             download=True, transform=transform_test)

# obtain training indices that will be used for validation
num_train = len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# prepare data loaders (combine dataset and sampler)
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
    sampler=train_sampler, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
    sampler=valid_sampler, num_workers=num_workers)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size,
    num_workers=num_workers)

# specify the image classes
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck']
# Out:
# 100%|██████████| 170M/170M [00:04<00:00, 42.5MB/s]

# %%
def imshow(img):
  img = img / 2 + 0.5  # unnormalize
  plt.imshow(np.transpose(img, (1, 2, 0)))

dataiter = iter(train_loader)
images, labels = next(dataiter)
images = images.numpy() # convert images to numpy for display

fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
  ax = fig.add_subplot(2, 10, idx+1, xticks=[], yticks=[])
  imshow(images[idx])
  ax.set_title(classes[labels[idx]])
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.8768656].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.8671105].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.7500488].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.2427812].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.7305385].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.7305385].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.41406673..1.6524973].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.8573554].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.8768656].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.2818017].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.8768656].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.8768656].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.6407346].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.7085817].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.8768656].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.7197279].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.8768656].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.7182741].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.3693457].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.3014984].

# %%
class BasicBlock(nn.Module):
  expansion = 1
  def __init__(self, in_planes, planes, stride=1):
    super(BasicBlock, self).__init__()
    self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(planes)
    self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(planes)

    self.shortcut = nn.Sequential()
    if stride != 1 or in_planes != self.expansion*planes:
      self.shortcut = nn.Sequential(
          nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
          nn.BatchNorm2d(self.expansion*planes)
      )

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.bn2(self.conv2(out))
    out += self.shortcut(x)
    out = F.relu(out)
    return out

class BottleNeck(nn.Module):
  expansion = 4

  def __init__(self, in_planes, planes, stride=1):
    super(BottleNeck, self).__init__()
    self.conv1 = nn.Conv2d(in_planes , planes, kernel_size=1, bias=False)
    self.bn1 = nn.BatchNorm2d(planes)
    self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(planes)
    self.conv3 = nn.Conv2d(planes, self.expansion*planes, kernel_size=1, bias=False)
    self.bn3 = nn.BatchNorm2d(self.expansion*planes)

    self.shortcut = nn.Sequential()
    if stride != 1 or in_planes != self.expansion*planes :
      self.shortcut = nn.Sequential(
          nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
          nn.BatchNorm2d(self.expansion*planes)
      )

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = F.relu(self.bn2(self.conv2(out)))
    out = self.bn3(self.conv3(out))
    out += self.shortcut(x)
    out = F.relu(out)
    return out

class ResNet(nn.Module):
  def __init__(self, block, num_blocks, num_classes=10):
    super(ResNet, self).__init__()
    self.in_planes = 64

    self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(64)
    self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
    self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
    self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
    self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
    self.linear = nn.Linear(512*block.expansion, num_classes)

  def _make_layer(self, block, planes, num_blocks, stride):
    strides = [stride] + [1]*(num_blocks-1)
    layers = []
    for stride in strides:
      layers.append(block(self.in_planes, planes, stride))
      self.in_planes = planes * block.expansion
    return nn.Sequential(*layers)

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.layer1(out)
    out = self.layer2(out)
    out = self.layer3(out)
    out = self.layer4(out)
    out = F.avg_pool2d(out, 4)
    out = out.view(out.size(0), -1)
    out = self.linear(out)
    return out

ResNet18 = ResNet(BasicBlock, [2,2,2,2])
#ResNet34 = ResNet(BasicBlock, [3,4,6,3])
#ResNet50 = ResNet(BottleNeck, [3,4,6,3])
#ResNet101 = ResNet(BottleNeck, [3,4,23,3])
#ResNet152 = ResNet(BottleNeck, [3,8,36,3])

print(ResNet18)

ResNet18 = torch.nn.DataParallel(ResNet18)
cudnn.benchmark = True
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(ResNet18.parameters(), lr=0.01, momentum=0.9, weight_decay=0.0001)
n_epochs = 200
valid_loss_min = np.inf

# %%
for epoch in range(1, n_epochs+1):
  train_loss = 0.0
  valid_loss = 0.0

  ResNet18.train()
  for batch_idx, (data, target) in enumerate(train_loader):
    data, target = data.cuda(), target.cuda()
    optimizer.zero_grad()
    output = ResNet18(data)
    loss = criterion(output, target)
    loss.backward()
    optimizer.step()
    train_loss += loss.item()*data.size(0)

  ResNet18.eval()
  for batch_idx, (data, target) in enumerate(valid_loader):
    # move tensors to GPU if CUDA is available
    data, target = data.cuda(), target.cuda()
    output = ResNet18(data)
    loss = criterion(output, target)
    valid_loss += loss.item()*data.size(0)

  train_loss = train_loss/len(train_loader.sampler)
  valid_loss = valid_loss/len(valid_loader.sampler)

  print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
      epoch, train_loss, valid_loss))

  if valid_loss <= valid_loss_min:
    print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
    valid_loss_min,
    valid_loss))
    torch.save(ResNet18.state_dict(), 'ResNet18.pt')
    valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 1.629155 	Validation Loss: 1.232524
# Validation loss decreased (inf --> 1.232524).  Saving model ...
# Epoch: 2 	Training Loss: 1.091231 	Validation Loss: 1.116634
# Validation loss decreased (1.232524 --> 1.116634).  Saving model ...
# Epoch: 3 	Training Loss: 0.854348 	Validation Loss: 0.777236
# Validation loss decreased (1.116634 --> 0.777236).  Saving model ...
# Epoch: 4 	Training Loss: 0.716126 	Validation Loss: 0.635028
# Validation loss decreased (0.777236 --> 0.635028).  Saving model ...
# Epoch: 5 	Training Loss: 0.622356 	Validation Loss: 0.584514
# Validation loss decreased (0.635028 --> 0.584514).  Saving model ...
# Epoch: 6 	Training Loss: 0.558455 	Validation Loss: 0.567834
# Validation loss decreased (0.584514 --> 0.567834).  Saving model ...
# Epoch: 7 	Training Loss: 0.503158 	Validation Loss: 0.529687
# Validation loss decreased (0.567834 --> 0.529687).  Saving model ...
# Epoch: 8 	Training Loss: 0.464303 	Validation Loss: 0.447522
# Validation loss decreased (0.529687 --> 0.447522).  Saving model ...
# Epoch: 9 	Training Loss: 0.430602 	Validation Loss: 0.457930
# Epoch: 10 	Training Loss: 0.395595 	Validation Loss: 0.437968
# Validation loss decreased (0.447522 --> 0.437968).  Saving model ...
# Epoch: 11 	Training Loss: 0.367614 	Validation Loss: 0.429998
# Validation loss decreased (0.437968 --> 0.429998).  Saving model ...
# Epoch: 12 	Training Loss: 0.346363 	Validation Loss: 0.393035
# Validation loss decreased (0.429998 --> 0.393035).  Saving model ...
# Epoch: 13 	Training Loss: 0.322742 	Validation Loss: 0.381897
# Validation loss decreased (0.393035 --> 0.381897).  Saving model ...
# Epoch: 14 	Training Loss: 0.302129 	Validation Loss: 0.371802
# Validation loss decreased (0.381897 --> 0.371802).  Saving model ...
# Epoch: 15 	Training Loss: 0.286897 	Validation Loss: 0.370270
# Validation loss decreased (0.371802 --> 0.370270).  Saving model ...
# Epoch: 16 	Training Loss: 0.272807 	Validation Loss: 0.359989
# Validation loss decreased (0.370270 --> 0.359989).  Saving model ...
# Epoch: 17 	Training Loss: 0.257039 	Validation Loss: 0.377459
# Epoch: 18 	Training Loss: 0.243983 	Validation Loss: 0.351063
# Validation loss decreased (0.359989 --> 0.351063).  Saving model ...
# Epoch: 19 	Training Loss: 0.227898 	Validation Loss: 0.383373
# Epoch: 20 	Training Loss: 0.213676 	Validation Loss: 0.342879
# Validation loss decreased (0.351063 --> 0.342879).  Saving model ...
# Epoch: 21 	Training Loss: 0.207076 	Validation Loss: 0.346948
# Epoch: 22 	Training Loss: 0.199614 	Validation Loss: 0.359819
# Epoch: 23 	Training Loss: 0.187442 	Validation Loss: 0.356714
# Epoch: 24 	Training Loss: 0.178524 	Validation Loss: 0.344157
# Epoch: 25 	Training Loss: 0.170178 	Validation Loss: 0.332130
# Validation loss decreased (0.342879 --> 0.332130).  Saving model ...
# Epoch: 26 	Training Loss: 0.164423 	Validation Loss: 0.328024
# Validation loss decreased (0.332130 --> 0.328024).  Saving model ...
# Epoch: 27 	Training Loss: 0.154665 	Validation Loss: 0.356382
# Epoch: 28 	Training Loss: 0.154183 	Validation Loss: 0.330870
# Epoch: 29 	Training Loss: 0.146891 	Validation Loss: 0.334037
# Epoch: 30 	Training Loss: 0.139119 	Validation Loss: 0.326430
# Validation loss decreased (0.328024 --> 0.326430).  Saving model ...
# Epoch: 31 	Training Loss: 0.137302 	Validation Loss: 0.326038
# Validation loss decreased (0.326430 --> 0.326038).  Saving model ...
# Epoch: 32 	Training Loss: 0.128199 	Validation Loss: 0.348454
# Epoch: 33 	Training Loss: 0.128779 	Validation Loss: 0.315385
# Validation loss decreased (0.326038 --> 0.315385).  Saving model ...
# Epoch: 34 	Training Loss: 0.121198 	Validation Loss: 0.321785
# Epoch: 35 	Training Loss: 0.118900 	Validation Loss: 0.328686
# Epoch: 36 	Training Loss: 0.115735 	Validation Loss: 0.338492
# Epoch: 37 	Training Loss: 0.111575 	Validation Loss: 0.325157
# Epoch: 38 	Training Loss: 0.106330 	Validation Loss: 0.309342
# Validation loss decreased (0.315385 --> 0.309342).  Saving model ...
# Epoch: 39 	Training Loss: 0.106021 	Validation Loss: 0.321226
# Epoch: 40 	Training Loss: 0.103601 	Validation Loss: 0.320866
# Epoch: 41 	Training Loss: 0.100025 	Validation Loss: 0.322518
# Epoch: 42 	Training Loss: 0.099280 	Validation Loss: 0.361301
# Epoch: 43 	Training Loss: 0.098677 	Validation Loss: 0.336338
# Epoch: 44 	Training Loss: 0.094344 	Validation Loss: 0.308472
# Validation loss decreased (0.309342 --> 0.308472).  Saving model ...
# Epoch: 45 	Training Loss: 0.093734 	Validation Loss: 0.309639
# Epoch: 46 	Training Loss: 0.087403 	Validation Loss: 0.354898
# Epoch: 47 	Training Loss: 0.092156 	Validation Loss: 0.333220
# Epoch: 48 	Training Loss: 0.091349 	Validation Loss: 0.321942
# Epoch: 49 	Training Loss: 0.085349 	Validation Loss: 0.350079
# Epoch: 50 	Training Loss: 0.083520 	Validation Loss: 0.325517
# Epoch: 51 	Training Loss: 0.087627 	Validation Loss: 0.330175
# Epoch: 52 	Training Loss: 0.086641 	Validation Loss: 0.331108
# Epoch: 53 	Training Loss: 0.084137 	Validation Loss: 0.325108
# Epoch: 54 	Training Loss: 0.086164 	Validation Loss: 0.358838
# Epoch: 55 	Training Loss: 0.078819 	Validation Loss: 0.325450
# Epoch: 56 	Training Loss: 0.081648 	Validation Loss: 0.339853
# Epoch: 57 	Training Loss: 0.079745 	Validation Loss: 0.355462
# Epoch: 58 	Training Loss: 0.074642 	Validation Loss: 0.334352
# Epoch: 59 	Training Loss: 0.076259 	Validation Loss: 0.356541
# Epoch: 60 	Training Loss: 0.082022 	Validation Loss: 0.344712
# Epoch: 61 	Training Loss: 0.073009 	Validation Loss: 0.339241
# Epoch: 62 	Training Loss: 0.079466 	Validation Loss: 0.351913
# Epoch: 63 	Training Loss: 0.078015 	Validation Loss: 0.332321
# Epoch: 64 	Training Loss: 0.072878 	Validation Loss: 0.309127
# Epoch: 65 	Training Loss: 0.078663 	Validation Loss: 0.332060
# Epoch: 66 	Training Loss: 0.076530 	Validation Loss: 0.325403
# Epoch: 67 	Training Loss: 0.073439 	Validation Loss: 0.315485
# Epoch: 68 	Training Loss: 0.078650 	Validation Loss: 0.345262
# Epoch: 69 	Training Loss: 0.069580 	Validation Loss: 0.326372
# Epoch: 70 	Training Loss: 0.071825 	Validation Loss: 0.322358
# Epoch: 71 	Training Loss: 0.067290 	Validation Loss: 0.339362
# Epoch: 72 	Training Loss: 0.071866 	Validation Loss: 0.376607
# Epoch: 73 	Training Loss: 0.074135 	Validation Loss: 0.327979
# Epoch: 74 	Training Loss: 0.069328 	Validation Loss: 0.383836
# Epoch: 75 	Training Loss: 0.072596 	Validation Loss: 0.331420
# Epoch: 76 	Training Loss: 0.068963 	Validation Loss: 0.383278
# Epoch: 77 	Training Loss: 0.066710 	Validation Loss: 0.351984
# Epoch: 78 	Training Loss: 0.070629 	Validation Loss: 0.326017
# Epoch: 79 	Training Loss: 0.067273 	Validation Loss: 0.336216
# Epoch: 80 	Training Loss: 0.072224 	Validation Loss: 0.313838
# Epoch: 81 	Training Loss: 0.067507 	Validation Loss: 0.312734
# Epoch: 82 	Training Loss: 0.070473 	Validation Loss: 0.385281
# Epoch: 83 	Training Loss: 0.069018 	Validation Loss: 0.354436
# Epoch: 84 	Training Loss: 0.066974 	Validation Loss: 0.385969
# Epoch: 85 	Training Loss: 0.070866 	Validation Loss: 0.327673
# Epoch: 86 	Training Loss: 0.070711 	Validation Loss: 0.322530
# Epoch: 87 	Training Loss: 0.068709 	Validation Loss: 0.327687
# Epoch: 88 	Training Loss: 0.067000 	Validation Loss: 0.334160
# Epoch: 89 	Training Loss: 0.062664 	Validation Loss: 0.322334
# Epoch: 90 	Training Loss: 0.068537 	Validation Loss: 0.329990
# Epoch: 91 	Training Loss: 0.069105 	Validation Loss: 0.327146
# Epoch: 92 	Training Loss: 0.065260 	Validation Loss: 0.302507
# Validation loss decreased (0.308472 --> 0.302507).  Saving model ...
# Epoch: 93 	Training Loss: 0.067032 	Validation Loss: 0.356670
# Epoch: 94 	Training Loss: 0.064982 	Validation Loss: 0.359683
# Epoch: 95 	Training Loss: 0.061198 	Validation Loss: 0.329384
# Epoch: 96 	Training Loss: 0.065660 	Validation Loss: 0.309986
# Epoch: 97 	Training Loss: 0.069465 	Validation Loss: 0.375618
# Epoch: 98 	Training Loss: 0.066185 	Validation Loss: 0.353354
# Epoch: 99 	Training Loss: 0.064875 	Validation Loss: 0.318837

# %%
ResNet18.load_state_dict(torch.load('ResNet18.pt'))
# Out:
# <All keys matched successfully>

# %%
test_loss = 0.0
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))

ResNet18.eval()
for batch_idx, (data, target) in enumerate(test_loader):
  data, target = data.cuda(), target.cuda()
  output = ResNet18(data)
  loss = criterion(output, target)
  test_loss += loss.item()*data.size(0)
  _, pred = torch.max(output, 1)
  correct_tensor = pred.eq(target.data.view_as(pred))
  correct = np.squeeze(correct_tensor.cpu().numpy())
  for i in range(batch_size):
    label = target.data[i]
    class_correct[label] += correct[i].item()
    class_total[label] += 1

# average test loss
test_loss = test_loss/len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(10):
  if class_total[i] > 0:
    print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
        classes[i], 100 * class_correct[i] / class_total[i],
        np.sum(class_correct[i]), np.sum(class_total[i])))
  else:
    print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.329196
#
# Test Accuracy of airplane: 92% (920/1000)
# Test Accuracy of automobile: 95% (956/1000)
# Test Accuracy of  bird: 86% (862/1000)
# Test Accuracy of   cat: 84% (840/1000)
# Test Accuracy of  deer: 89% (896/1000)
# Test Accuracy of   dog: 86% (864/1000)
# Test Accuracy of  frog: 94% (946/1000)
# Test Accuracy of horse: 90% (904/1000)
# Test Accuracy of  ship: 94% (942/1000)
# Test Accuracy of truck: 94% (948/1000)
#
# Test Accuracy (Overall): 90% (9078/10000)

# %%
import matplotlib.pyplot as plt

accuracies = [100 * class_correct[i] / class_total[i] if class_total[i] > 0 else 0 for i in range(10)]

plt.bar(classes, accuracies)
plt.ylabel('Accuracy (%)')
plt.title('Per-Class Accuracy')
plt.show()
